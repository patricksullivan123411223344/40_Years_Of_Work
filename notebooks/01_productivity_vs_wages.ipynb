# %% [raw]
# Responsibilities:
# - Merge productivity index with median hourly compensation.
# - Convert to real 2025 USD.
# - Plot ratio + % divergence since 1970.

# %%
import pandas as pd 

df = pd.read_csv("../data/raw/wages_productivity_data.csv")
df.info()
df.head(10)
df.describe()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("../data/raw/wages_productivity_data.csv")
#       4 df.info()
#
# ModuleNotFoundError: No module named 'pandas'
