# %%
Responsibilities:
- Pull total amount of overtime worked each year + compensation for said overtime.
- Show the differences throughout each year, marking where overtime starts becoming more common and compensation becomes unexpected.
