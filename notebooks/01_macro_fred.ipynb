# %%
import pandas as pd 
import numpy as np

df = pd.read_csv("../data/raw/wages_productivity_data.csv")
df.info()
df.head(10)
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182 entries, 0 to 181
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     182 non-null    object
#  1   Productivity                   182 non-null    float64
#  2   Real Hourly Compensation       182 non-null    float64
#  3   Hourly Compensation (Nominal)  182 non-null    float64
#  4   Labor Share                    182 non-null    float64
#  5   Unit Labor Costs               182 non-null    float64
#  6   Hours Worked                   182 non-null    float64
# dtypes: float64(6), object(1)
# memory usage: 10.1+ KB
#        Productivity  Real Hourly Compensation  Hourly Compensation (Nominal)  \
# count    182.000000                182.000000                     182.000000
# mean      78.759698                 88.276610                      70.283236
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/raw/fred/macro_demographs.csv")
df.info()
df.head(10)
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 8 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Unnamed: 0                    548 non-null    object
#  1   Average Weekly Earnings All   234 non-null    float64
#  2   Median Weekly Earnings Men    45 non-null     float64
#  3   Median Weekly Earnings Women  45 non-null     float64
#  4   Employment Pop Ratio          548 non-null    float64
#  5   Labor Force Participation     548 non-null    float64
#  6   Unemployment Rate Men         548 non-null    float64
#  7   Unemployment Rate Women       548 non-null    float64
# dtypes: float64(7), object(1)
# memory usage: 34.4+ KB
#        Average Weekly Earnings All  Median Weekly Earnings Men  \
# count                   234.000000                   45.000000
# mean                     26.474701                  623.800000
# ...
