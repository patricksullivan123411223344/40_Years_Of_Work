# %%
Responsibilities:
- Create master DataFrame.
- Compute composiste inequality index = weighted z-score of divergence.
- Produce final visualizations that will be linked on Next site. 
- Draft summary paragraphs directly in Markdown cells --> export to PDF/HTML
