# %%
Responsibilities:
- Annotate timeline of precidency, policy, and effect on economy. 
- Mark inflection points that could have influenced current policies. 
- Overlay with changes in CEO ratio / labor share.
